# %% [markdown]
# ## Julia on Colaboratory ##
#
# [Colaboratory](https://colab.research.google.com) does not provide native support for the [Julia programming language](https://julialang.org). However, since Colaboratory gives you root access to the machine that runs your notebook (the *“runtime”* in Colaboratory terminology), we can install Julia support by uploading a specially crafted Julia notebook  – *this* notebook. We then install Julia and [IJulia](https://github.com/JuliaLang/IJulia.jl) ([Jupyter](https://jupyter.org)/Colaboratory notebook support) and reload the notebook so that Colaboratory detects and initiates what we installed.
#
# In brief:
#
# 1. **Run the cell below**
# 2. **Reload the page**
# 3. **Edit the notebook name and start hacking Julia code below**
#
# **If your runtime resets**, either manually or if left idle for some time, **repeat steps 1 and 2**.
#
# ### Acknowledgements ###
#
# This hack by Pontus Stenetorp is an adaptation of [James Bradbury’s original Colaboratory Julia hack](https://discourse.julialang.org/t/julia-on-google-colab-free-gpu-accelerated-shareable-notebooks/15319/27), that broke some time in September 2019 as Colaboratory increased their level of notebook runtime isolation. There also appears to be CUDA compilation support installed by default for each notebook runtime type in October 2019, which shaves off a good 15 minutes or so from the original hack’s installation time.

# %%
# Installation cell
%%shell
if ! command -v julia 2>&1 > /dev/null
then
    wget 'https://julialang-s3.julialang.org/bin/linux/x64/1.3/julia-1.3.1-linux-x86_64.tar.gz' \
        -O /tmp/julia.tar.gz
    tar -x -f /tmp/julia.tar.gz -C /usr/local --strip-components 1
    rm /tmp/julia.tar.gz
fi
julia -e 'using Pkg; pkg"add Plots; add PyPlot; add IJulia; add Knet;"'
julia -e 'using Pkg; pkg"build Knet;"'
# Out:
# --2020-05-18 11:49:45--  https://julialang-s3.julialang.org/bin/linux/x64/1.3/julia-1.3.1-linux-x86_64.tar.gz
# Resolving julialang-s3.julialang.org (julialang-s3.julialang.org)... 151.101.2.49, 151.101.66.49, 151.101.130.49, ...
# Connecting to julialang-s3.julialang.org (julialang-s3.julialang.org)|151.101.2.49|:443... connected.
# HTTP request sent, awaiting response... 302 gce internal redirect trigger
# Location: https://storage.googleapis.com/julialang2/bin/linux/x64/1.3/julia-1.3.1-linux-x86_64.tar.gz [following]
# --2020-05-18 11:49:45--  https://storage.googleapis.com/julialang2/bin/linux/x64/1.3/julia-1.3.1-linux-x86_64.tar.gz
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.195.128, 2607:f8b0:400e:c09::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.195.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 95929584 (91M) [application/x-gzip]
# Saving to: ‘/tmp/julia.tar.gz’
#
# /tmp/julia.tar.gz   100%[===================>]  91.49M  59.0MB/s    in 1.6s
#
# 2020-05-18 11:49:47 (59.0 MB/s) - ‘/tmp/julia.tar.gz’ saved [95929584/95929584]
#
#    Cloning default registries into `~/.julia`
#    Cloning registry from "https://github.com/JuliaRegistries/General.git"
#      Added registry `General` to `~/.julia/registries/General`
#  Resolving package versions...
#  Installed Bzip2_jll ────────── v1.0.6+2
#  Installed NaNMath ──────────── v0.3.3
#  Installed libvorbis_jll ────── v1.3.6+4
#  Installed LibVPX_jll ───────── v1.8.1+1
#  Installed x265_jll ─────────── v3.0.0+1
#  Installed PlotUtils ────────── v1.0.3
#  Installed Plots ────────────── v1.2.6
#  Installed StatsBase ────────── v0.33.0
#  Installed Measures ─────────── v0.3.1
#  Installed FFMPEG ───────────── v0.3.0
#  Installed FriBidi_jll ──────── v1.0.5+3
#  Installed DataAPI ──────────── v1.3.0
#  Installed GeometryTypes ────── v0.8.3
#  Installed OpenSSL_jll ──────── v1.1.1+2
#  Installed Showoff ──────────── v0.3.1
#  Installed PlotThemes ───────── v2.0.0
#  Installed RecipesBase ──────── v1.0.1
#  Installed FreeType2_jll ────── v2.10.1+2
#  Installed Zlib_jll ─────────── v1.2.11+9
#  Installed DataStructures ───── v0.17.16
#  Installed Requires ─────────── v1.0.1
#  Installed ColorTypes ───────── v0.10.3
#  Installed StaticArrays ─────── v0.12.3
#  Installed x264_jll ─────────── v2019.5.25+2
#  Installed FixedPointNumbers ── v0.8.0
#  Installed Parsers ──────────── v1.0.4
#  Installed JSON ─────────────── v0.21.0
#  Installed Colors ───────────── v0.12.0
#  Installed SortingAlgorithms ── v0.3.1
#  Installed Reexport ─────────── v0.2.0
#  Installed OrderedCollections ─ v1.2.0
#  Installed FFMPEG_jll ───────── v4.1.0+3
#  Installed libfdk_aac_jll ───── v0.1.6+2
#  Installed RecipesPipeline ──── v0.1.9
#  Installed libass_jll ───────── v0.14.0+2
#  Installed Ogg_jll ──────────── v1.3.4+0
#  Installed Contour ──────────── v0.5.3
#  Installed Missings ─────────── v0.4.3
#  Installed LAME_jll ─────────── v3.100.0+1
#  Installed GR ───────────────── v0.49.1
#  Installed Opus_jll ─────────── v1.3.1+1
#  Installed ColorSchemes ─────── v3.9.0
#   Updating `~/.julia/environments/v1.3/Project.toml`
#   [91a5bcdd] + Plots v1.2.6
#   Updating `~/.julia/environments/v1.3/Manifest.toml`
#   [6e34b625] + Bzip2_jll v1.0.6+2
#   [35d6a980] + ColorSchemes v3.9.0
#   [3da002f7] + ColorTypes v0.10.3
#   [5ae59095] + Colors v0.12.0
#   [d38c429a] + Contour v0.5.3
#   [9a962f9c] + DataAPI v1.3.0
#   [864edb3b] + DataStructures v0.17.16
#   [c87230d0] + FFMPEG v0.3.0
#   [b22a6f82] + FFMPEG_jll v4.1.0+3
#   [53c48c17] + FixedPointNumbers v0.8.0
#   [d7e528f0] + FreeType2_jll v2.10.1+2
#   [559328eb] + FriBidi_jll v1.0.5+3
#   [28b8d3ca] + GR v0.49.1
#   [4d00f742] + GeometryTypes v0.8.3
#   [682c06a0] + JSON v0.21.0
#   [c1c5ebd0] + LAME_jll v3.100.0+1
#   [dd192d2f] + LibVPX_jll v1.8.1+1
#   [442fdcdd] + Measures v0.3.1
#   [e1d29d7a] + Missings v0.4.3
#   [77ba4419] + NaNMath v0.3.3
#   [e7412a2a] + Ogg_jll v1.3.4+0
#   [458c3c95] + OpenSSL_jll v1.1.1+2
#   [91d4177d] + Opus_jll v1.3.1+1
#   [bac558e1] + OrderedCollections v1.2.0
#   [69de0a69] + Parsers v1.0.4
#   [ccf2f8ad] + PlotThemes v2.0.0
#   [995b91a9] + PlotUtils v1.0.3
#   [91a5bcdd] + Plots v1.2.6
#   [3cdcf5f2] + RecipesBase v1.0.1
#   [01d81517] + RecipesPipeline v0.1.9
#   [189a3867] + Reexport v0.2.0
#   [ae029012] + Requires v1.0.1
#   [992d4aef] + Showoff v0.3.1
#   [a2af1166] + SortingAlgorithms v0.3.1
#   [90137ffa] + StaticArrays v0.12.3
#   [2913bbd2] + StatsBase v0.33.0
#   [83775a58] + Zlib_jll v1.2.11+9
#   [0ac62f75] + libass_jll v0.14.0+2
#   [f638f0a6] + libfdk_aac_jll v0.1.6+2
#   [f27f6e37] + libvorbis_jll v1.3.6+4
#   [1270edf5] + x264_jll v2019.5.25+2
#   [dfaa095f] + x265_jll v3.0.0+1
#   [2a0f44e3] + Base64
#   [ade2ca70] + Dates
#   [8bb1440f] + DelimitedFiles
#   [8ba89e20] + Distributed
#   [b77e0a4c] + InteractiveUtils
#   [76f85450] + LibGit2
#   [8f399da3] + Libdl
#   [37e2e46d] + LinearAlgebra
#   [56ddb016] + Logging
#   [d6f4376e] + Markdown
#   [a63ad114] + Mmap
#   [44cfe95a] + Pkg
#   [de0858da] + Printf
#   [3fa0cd96] + REPL
#   [9a3f8284] + Random
#   [ea8e919c] + SHA
#   [9e88b42a] + Serialization
#   [6462fe0b] + Sockets
#   [2f01184e] + SparseArrays
#   [10745b16] + Statistics
#   [8dfed614] + Test
#   [cf7118a7] + UUIDs
#   [4ec0a83e] + Unicode
#   Building GR ───→ `~/.julia/packages/GR/cRdXQ/deps/build.log`
#   Building Plots → `~/.julia/packages/Plots/Vfmes/deps/build.log`
#  Resolving package versions...
#  Installed LaTeXStrings ─── v1.1.0
#  Installed VersionParsing ─ v1.2.0
#  Installed PyPlot ───────── v2.9.0
#  Installed MacroTools ───── v0.5.5
#  Installed Conda ────────── v1.4.1
#  Installed PyCall ───────── v1.91.4
#   Updating `~/.julia/environments/v1.3/Project.toml`
#   [d330b81b] + PyPlot v2.9.0
#   Updating `~/.julia/environments/v1.3/Manifest.toml`
#   [8f4d0f93] + Conda v1.4.1
#   [b964fa9f] + LaTeXStrings v1.1.0
#   [1914dd2f] + MacroTools v0.5.5
#   [438e738f] + PyCall v1.91.4
#   [d330b81b] + PyPlot v2.9.0
#   [81def892] + VersionParsing v1.2.0
#   Building Conda ─→ `~/.julia/packages/Conda/3rPhK/deps/build.log`
#   Building PyCall → `~/.julia/packages/PyCall/zqDXB/deps/build.log`
#  Resolving package versions...
#  Installed SoftGlobalScope ─ v1.0.10
#  Installed ZeroMQ_jll ────── v4.3.2+2
#  Installed MbedTLS_jll ───── v2.16.0+2
#  Installed ZMQ ───────────── v1.2.0
#  Installed IJulia ────────── v1.21.2
#  Installed MbedTLS ───────── v1.0.2
#   Updating `~/.julia/environments/v1.3/Project.toml`
#   [7073ff75] + IJulia v1.21.2
#   Updating `~/.julia/environments/v1.3/Manifest.toml`
#   [7073ff75] + IJulia v1.21.2
#   [739be429] + MbedTLS v1.0.2
#   [c8ffd9c3] + MbedTLS_jll v2.16.0+2
#   [b85f4697] + SoftGlobalScope v1.0.10
#   [c2297ded] + ZMQ v1.2.0
#   [8f1865be] + ZeroMQ_jll v4.3.2+2
#   [7b1f6079] + FileWatching
#   Building IJulia → `~/.julia/packages/IJulia/DrVMH/deps/build.log`
#  Resolving package versions...
#  Installed TimerOutputs ───────────────── v0.5.5
#  Installed GPUArrays ──────────────────── v3.3.0
#  Installed CompilerSupportLibraries_jll ─ v0.3.3+0
#  Installed AutoGrad ───────────────────── v1.2.1
#  Installed Cthulhu ────────────────────── v1.1.1
#  Installed NNlib ──────────────────────── v0.6.6
#  Installed CuArrays ───────────────────── v2.2.0
#  Installed CodecZlib ──────────────────── v0.7.0
#  Installed CEnum ──────────────────────── v0.3.0
#  Installed SpecialFunctions ───────────── v0.10.2
#  Installed ExprTools ──────────────────── v0.1.1
#  Installed GPUCompiler ────────────────── v0.2.0
#  Installed CUDAapi ────────────────────── v4.0.0
#  Installed CodeTracking ───────────────── v0.5.11
#  Installed AbstractFFTs ───────────────── v0.5.0
#  Installed JLD2 ───────────────────────── v0.1.13
#  Installed LLVM ───────────────────────── v1.4.1
#  Installed CUDAdrv ────────────────────── v6.3.0
#  Installed Adapt ──────────────────────── v1.0.1
#  Installed CUDAnative ─────────────────── v3.1.0
#  Installed TranscodingStreams ─────────── v0.9.5
#  Installed Knet ───────────────────────── v1.3.5
#  Installed BinaryProvider ─────────────── v0.5.9
#  Installed OpenSpecFun_jll ────────────── v0.5.3+3
#  Installed FileIO ─────────────────────── v1.3.0
#   Updating `~/.julia/environments/v1.3/Project.toml`
#   [1902f260] + Knet v1.3.5
#   Updating `~/.julia/environments/v1.3/Manifest.toml`
#   [621f4979] + AbstractFFTs v0.5.0
#   [79e6a3ab] + Adapt v1.0.1
#   [6710c13c] + AutoGrad v1.2.1
#   [b99e7846] + BinaryProvider v0.5.9
#   [fa961155] + CEnum v0.3.0
#   [3895d2a7] + CUDAapi v4.0.0
#   [c5f51814] + CUDAdrv v6.3.0
#   [be33ccc6] + CUDAnative v3.1.0
#   [da1fd8a2] + CodeTracking v0.5.11
#   [944b1d66] + CodecZlib v0.7.0
#   [e66e0078] + CompilerSupportLibraries_jll v0.3.3+0
#   [f68482b8] + Cthulhu v1.1.1
#   [3a865a2d] + CuArrays v2.2.0
#   [e2ba6199] + ExprTools v0.1.1
#   [5789e2e9] + FileIO v1.3.0
#   [0c68f7d7] + GPUArrays v3.3.0
#   [61eb1bfa] + GPUCompiler v0.2.0
#   [033835bb] + JLD2 v0.1.13
#   [1902f260] + Knet v1.3.5
#   [929cbde3] + LLVM v1.4.1
#   [872c559c] + NNlib v0.6.6
#   [efe28fd5] + OpenSpecFun_jll v0.5.3+3
#   [276daf66] + SpecialFunctions v0.10.2
#   [a759f4b9] + TimerOutputs v0.5.5
#   [3bb67fe8] + TranscodingStreams v0.9.5
#   Building NNlib → `~/.julia/packages/NNlib/FAI3o/deps/build.log`
#   Building Knet ─→ `~/.julia/packages/Knet/bTNMd/deps/build.log`
#   Building NNlib → `~/.julia/packages/NNlib/FAI3o/deps/build.log`
#   Building Knet ─→ `~/.julia/packages/Knet/bTNMd/deps/build.log`

# %%
using Knet
# Test if Knet is using gpu
Knet.gpu()
# Out:
# ┌ Info: Precompiling Knet [1902f260-5fb4-5aff-8c31-6271790ab950]
# └ @ Base loading.jl:1273
# 0

# %%
a = KnetArray(randn(4,4))
sigm.(a)
# Out:
# 4×4 KnetArray{Float64,2}:
#  0.554472  0.52774   0.497022  0.154425
#  0.66232   0.292151  0.38498   0.668314
#  0.841404  0.547291  0.380908  0.670597
#  0.187157  0.518183  0.434034  0.78085

# %%
#constant variables
random_seed         = 12345;
BATCH_SIZE          = 100;
LEARNING_RATE       = 0.15;
EPOCH               = 100;
SCALE               = 0.01;
ninputs             = 784;
noutputs            = 10;
atype = gpu() >= 0  ? KnetArray{Float32} : Array{Float32}
# Out:
# KnetArray{Float32,N} where N

# %%
using Pkg; for p in ("Knet","IterTools","Plots"); haskey(Pkg.installed(),p) || Pkg.add(p); end
using Knet, Printf, Random
include(Knet.dir("data", "mnist.jl"))

xtrn, ytrn, xtst, ytst = mnist()
dtrn = minibatch(xtrn[:,:,:,1:100], ytrn[1:100], BATCH_SIZE; xtype=atype)
dtst = minibatch(xtst[:,:,:,1:100], ytst[1:100], BATCH_SIZE; xtype=atype)

println.(summary.((xtrn, xtst, ytrn, ytst)));
println.(summary.((dtrn, dtst)));
# Out:
# ┌ Info: Loading MNIST...
# └ @ Main /root/.julia/packages/Knet/bTNMd/data/mnist.jl:33
# 28×28×1×60000 Array{Float32,4}
# 28×28×1×10000 Array{Float32,4}
# 60000-element Array{UInt8,1}
# 10000-element Array{UInt8,1}
# 1-element Knet.Data{Tuple{KnetArray{Float32,4},Array{UInt8,1}}}
# 1-element Knet.Data{Tuple{KnetArray{Float32,4},Array{UInt8,1}}}

# %%
# define onehot function
function to_onehot(x)
    onehot = zeros(10, 1)
    onehot[x, 1] = 1.0
    return onehot
end
# Out:
# to_onehot (generic function with 1 method)

# %%
## Loading the data and set random.seed 
Random.seed!(random_seed)
xtrn = reshape(xtrn, 784, 60000)
xtst = reshape(xtst, 784, 10000)
ytrn = hcat(map(to_onehot, ytrn)...)
ytst = hcat(map(to_onehot, ytst)...)
size(xtrn),size(xtst),size(ytrn),size(ytst)
# Out:
# ((784, 60000), (784, 10000), (10, 60000), (10, 10000))

# %%
struct Linear; w; b; end

# %%
function Linear(xsize::Int, ysize::Int, SCALE=0.1)
    return Linear(SCALE * randn(ysize,xsize), zeros(ysize,1))
end
# Out:
# Linear

# %%
function custom_minibatch(X, Y)
    data = Any[]
    for i=1:BATCH_SIZE:size(X,2)
        j= min(i + BATCH_SIZE - 1, size(X,2))
        push!(data, ((X[:,i:j]), Y[:,i:j]))
    end
    return data
end
# Out:
# custom_minibatch (generic function with 1 method)

# %%
# define struct in W and b values 
model    = Linear(ninputs, noutputs)
trn_data = custom_minibatch(xtrn, ytrn)
size(trn_data), size(model.w), size(model.b)
# Out:
# ((600,), (10, 784), (10, 1))

# %%
function softmax_function(W, b, x)
    calculator = exp.((W * x) .+ b)
    return calculator ./ sum(calculator, dims=1)
end
# Out:
# softmax_function (generic function with 1 method)

# %%
# define loss function
function softmax_back_and_loss(W, b, x, ygold)   
    loss = -sum(ygold .* (log.(softmax_function(W,b,x)))) / size(x,2)
    grad_b = sum( -(ygold-softmax_function(W,b,x)) / size(x,2), dims=2)
    grad_W =  -(ygold-softmax_function(W,b,x)) / size(x,2) * x'
    return loss, grad_W, grad_b
end
# Out:
# softmax_back_and_loss (generic function with 1 method)

# %%
# define train function
function train(W, b, data)
    totalcost = 0.0; numins = 0;
    for (x, y) in data
        loss, grad_W, grad_b =softmax_back_and_loss(W, b, x, y)        
        W  .-=  LEARNING_RATE * grad_W
        b  .-=  LEARNING_RATE * grad_b
        totalcost += loss .* size(x,2)
        numins += size(x,2)
    end
    avgcost = totalcost / numins
end
# Out:
# train (generic function with 1 method)

# %%
# define accuary function
function accuracy(ygold, ypred)
    correct = 0.0
    for i=1:size(ygold, 2)
        correct += findmax(ygold[:,i]; dims=1)[2] == findmax(ypred[:, i]; dims=1)[2] ? 1.0 : 0.0
    end
    return correct / size(ygold, 2)
end
# Out:
# accuracy (generic function with 1 method)

# %%
for i=1:EPOCH
    cost = train(model.w, model.b, trn_data)
    pred = softmax_function(model.w, model.b, xtrn)
    trnacc = accuracy(ytrn, pred)
    pred = softmax_function(model.w, model.b, xtst)
    tstacc = accuracy(ytst, pred)
    @printf("epoch: %d softloss: %g trn accuracy: %g tst accuracy: %g\n", i, cost, trnacc, tstacc)
end
# Out:
# epoch: 1 softloss: 0.501781 trn accuracy: 0.895183 tst accuracy: 0.9015
# epoch: 2 softloss: 0.344278 trn accuracy: 0.905517 tst accuracy: 0.91
# epoch: 3 softloss: 0.319777 trn accuracy: 0.910433 tst accuracy: 0.9129
# epoch: 4 softloss: 0.306857 trn accuracy: 0.91345 tst accuracy: 0.9141
# epoch: 5 softloss: 0.298475 trn accuracy: 0.9154 tst accuracy: 0.9163
# epoch: 6 softloss: 0.292434 trn accuracy: 0.917267 tst accuracy: 0.9172
# epoch: 7 softloss: 0.28779 trn accuracy: 0.9185 tst accuracy: 0.9182
# epoch: 8 softloss: 0.284058 trn accuracy: 0.9197 tst accuracy: 0.919
# epoch: 9 softloss: 0.280963 trn accuracy: 0.9203 tst accuracy: 0.919
# epoch: 10 softloss: 0.278336 trn accuracy: 0.920983 tst accuracy: 0.9193
# epoch: 11 softloss: 0.276062 trn accuracy: 0.921767 tst accuracy: 0.92
# epoch: 12 softloss: 0.274067 trn accuracy: 0.922333 tst accuracy: 0.9201
# epoch: 13 softloss: 0.272293 trn accuracy: 0.9229 tst accuracy: 0.9208
# epoch: 14 softloss: 0.2707 trn accuracy: 0.923533 tst accuracy: 0.921
# epoch: 15 softloss: 0.269259 trn accuracy: 0.923833 tst accuracy: 0.9214
# epoch: 16 softloss: 0.267944 trn accuracy: 0.924017 tst accuracy: 0.9219
# epoch: 17 softloss: 0.266736 trn accuracy: 0.924317 tst accuracy: 0.9219
# epoch: 18 softloss: 0.265622 trn accuracy: 0.924633 tst accuracy: 0.9221
# epoch: 19 softloss: 0.264589 trn accuracy: 0.92495 tst accuracy: 0.9222
# epoch: 20 softloss: 0.263626 trn accuracy: 0.9253 tst accuracy: 0.9226
# epoch: 21 softloss: 0.262725 trn accuracy: 0.9257 tst accuracy: 0.9225
# epoch: 22 softloss: 0.26188 trn accuracy: 0.9262 tst accuracy: 0.9225
# epoch: 23 softloss: 0.261085 trn accuracy: 0.92655 tst accuracy: 0.9225
# epoch: 24 softloss: 0.260334 trn accuracy: 0.926767 tst accuracy: 0.9226
# epoch: 25 softloss: 0.259623 trn accuracy: 0.927033 tst accuracy: 0.9226
# epoch: 26 softloss: 0.258948 trn accuracy: 0.92735 tst accuracy: 0.923
# epoch: 27 softloss: 0.258307 trn accuracy: 0.927533 tst accuracy: 0.923
# epoch: 28 softloss: 0.257696 trn accuracy: 0.927717 tst accuracy: 0.9229
# epoch: 29 softloss: 0.257112 trn accuracy: 0.9279 tst accuracy: 0.9227
# epoch: 30 softloss: 0.256555 trn accuracy: 0.928083 tst accuracy: 0.9226
# epoch: 31 softloss: 0.25602 trn accuracy: 0.928317 tst accuracy: 0.9225
# epoch: 32 softloss: 0.255508 trn accuracy: 0.928417 tst accuracy: 0.9228
# epoch: 33 softloss: 0.255016 trn accuracy: 0.9286 tst accuracy: 0.9232
# epoch: 34 softloss: 0.254543 trn accuracy: 0.928783 tst accuracy: 0.9229
# epoch: 35 softloss: 0.254087 trn accuracy: 0.928933 tst accuracy: 0.9229
# epoch: 36 softloss: 0.253648 trn accuracy: 0.929017 tst accuracy: 0.9228
# epoch: 37 softloss: 0.253224 trn accuracy: 0.929133 tst accuracy: 0.9228
# epoch: 38 softloss: 0.252815 trn accuracy: 0.92935 tst accuracy: 0.9231
# epoch: 39 softloss: 0.252419 trn accuracy: 0.92955 tst accuracy: 0.9232
# epoch: 40 softloss: 0.252037 trn accuracy: 0.929633 tst accuracy: 0.9231
# epoch: 41 softloss: 0.251666 trn accuracy: 0.9298 tst accuracy: 0.9231
# epoch: 42 softloss: 0.251306 trn accuracy: 0.929883 tst accuracy: 0.9232
# epoch: 43 softloss: 0.250957 trn accuracy: 0.929983 tst accuracy: 0.9232
# epoch: 44 softloss: 0.250619 trn accuracy: 0.930183 tst accuracy: 0.9231
# epoch: 45 softloss: 0.25029 trn accuracy: 0.930333 tst accuracy: 0.923
# epoch: 46 softloss: 0.24997 trn accuracy: 0.930433 tst accuracy: 0.9229
# epoch: 47 softloss: 0.249659 trn accuracy: 0.930483 tst accuracy: 0.923
# epoch: 48 softloss: 0.249357 trn accuracy: 0.930533 tst accuracy: 0.9232
# epoch: 49 softloss: 0.249062 trn accuracy: 0.930567 tst accuracy: 0.9233
# epoch: 50 softloss: 0.248775 trn accuracy: 0.93065 tst accuracy: 0.9234
# epoch: 51 softloss: 0.248495 trn accuracy: 0.93075 tst accuracy: 0.9234
# epoch: 52 softloss: 0.248222 trn accuracy: 0.93085 tst accuracy: 0.9234
# epoch: 53 softloss: 0.247956 trn accuracy: 0.9309 tst accuracy: 0.9236
# epoch: 54 softloss: 0.247695 trn accuracy: 0.931067 tst accuracy: 0.9235
# epoch: 55 softloss: 0.247441 trn accuracy: 0.9311 tst accuracy: 0.9235
# epoch: 56 softloss: 0.247193 trn accuracy: 0.931133 tst accuracy: 0.9237
# epoch: 57 softloss: 0.24695 trn accuracy: 0.93115 tst accuracy: 0.9237
# epoch: 58 softloss: 0.246713 trn accuracy: 0.931283 tst accuracy: 0.9236
# epoch: 59 softloss: 0.246481 trn accuracy: 0.931367 tst accuracy: 0.9236
# epoch: 60 softloss: 0.246253 trn accuracy: 0.931333 tst accuracy: 0.9237
# epoch: 61 softloss: 0.246031 trn accuracy: 0.931417 tst accuracy: 0.9237
# epoch: 62 softloss: 0.245813 trn accuracy: 0.931367 tst accuracy: 0.9237
# epoch: 63 softloss: 0.245599 trn accuracy: 0.93155 tst accuracy: 0.9238
# epoch: 64 softloss: 0.24539 trn accuracy: 0.931633 tst accuracy: 0.9238
# epoch: 65 softloss: 0.245185 trn accuracy: 0.931717 tst accuracy: 0.9239
# epoch: 66 softloss: 0.244984 trn accuracy: 0.931767 tst accuracy: 0.9239
# epoch: 67 softloss: 0.244787 trn accuracy: 0.931783 tst accuracy: 0.924
# epoch: 68 softloss: 0.244593 trn accuracy: 0.93185 tst accuracy: 0.9241
# epoch: 69 softloss: 0.244403 trn accuracy: 0.9319 tst accuracy: 0.924
# epoch: 70 softloss: 0.244216 trn accuracy: 0.931983 tst accuracy: 0.924
# epoch: 71 softloss: 0.244033 trn accuracy: 0.93205 tst accuracy: 0.9241
# epoch: 72 softloss: 0.243853 trn accuracy: 0.9322 tst accuracy: 0.9243
# epoch: 73 softloss: 0.243676 trn accuracy: 0.932283 tst accuracy: 0.9241
# epoch: 74 softloss: 0.243502 trn accuracy: 0.93225 tst accuracy: 0.9244
# epoch: 75 softloss: 0.243331 trn accuracy: 0.932317 tst accuracy: 0.9244
# epoch: 76 softloss: 0.243163 trn accuracy: 0.9323 tst accuracy: 0.9243
# epoch: 77 softloss: 0.242998 trn accuracy: 0.9323 tst accuracy: 0.9244
# epoch: 78 softloss: 0.242836 trn accuracy: 0.932383 tst accuracy: 0.9244
# epoch: 79 softloss: 0.242676 trn accuracy: 0.932417 tst accuracy: 0.9243
# epoch: 80 softloss: 0.242518 trn accuracy: 0.932517 tst accuracy: 0.9244
# epoch: 81 softloss: 0.242364 trn accuracy: 0.932533 tst accuracy: 0.9246
# epoch: 82 softloss: 0.242211 trn accuracy: 0.932567 tst accuracy: 0.9245
# epoch: 83 softloss: 0.242061 trn accuracy: 0.9326 tst accuracy: 0.9245
# epoch: 84 softloss: 0.241913 trn accuracy: 0.932533 tst accuracy: 0.9245
# epoch: 85 softloss: 0.241768 trn accuracy: 0.932583 tst accuracy: 0.9243
# epoch: 86 softloss: 0.241624 trn accuracy: 0.932667 tst accuracy: 0.9243
# epoch: 87 softloss: 0.241483 trn accuracy: 0.932667 tst accuracy: 0.9243
# epoch: 88 softloss: 0.241343 trn accuracy: 0.932733 tst accuracy: 0.9242
# epoch: 89 softloss: 0.241206 trn accuracy: 0.9328 tst accuracy: 0.9241
# epoch: 90 softloss: 0.241071 trn accuracy: 0.932883 tst accuracy: 0.9239
# epoch: 91 softloss: 0.240937 trn accuracy: 0.932933 tst accuracy: 0.9239
# epoch: 92 softloss: 0.240806 trn accuracy: 0.9329 tst accuracy: 0.9238
# epoch: 93 softloss: 0.240676 trn accuracy: 0.932883 tst accuracy: 0.9238
# epoch: 94 softloss: 0.240548 trn accuracy: 0.932883 tst accuracy: 0.9238
# epoch: 95 softloss: 0.240421 trn accuracy: 0.93295 tst accuracy: 0.9237
# epoch: 96 softloss: 0.240297 trn accuracy: 0.933 tst accuracy: 0.9235
# epoch: 97 softloss: 0.240174 trn accuracy: 0.933033 tst accuracy: 0.9235
# epoch: 98 softloss: 0.240052 trn accuracy: 0.9331 tst accuracy: 0.9235
# epoch: 99 softloss: 0.239932 trn accuracy: 0.93315 tst accuracy: 0.9235
# epoch: 100 softloss: 0.239814 trn accuracy: 0.9332 tst accuracy: 0.9235
